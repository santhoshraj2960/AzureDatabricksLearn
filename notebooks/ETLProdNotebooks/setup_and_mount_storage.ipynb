# %%
# feature comment

# %%
configs = {
  "dfs.adls.oauth2.access.token.provider.type": "ClientCredential",
  "dfs.adls.oauth2.client.id": dbutils.secrets.get(scope="azure_datalake_scope",key="datalake_gen1_clientid"),
  "dfs.adls.oauth2.credential": dbutils.secrets.get(scope="azure_datalake_scope",key="datalake_gen1_secret"),
  "dfs.adls.oauth2.refresh.url": "https://login.microsoftonline.com/{}/oauth2/token".format(dbutils.secrets.get(scope="azure_datalake_scope",key="datalake_gen1_tenant_id"),)
}

dbutils.fs.mount(
  source = "adl://datalake165.azuredatalakestore.net",
  mount_point = "/mnt/datalake",
  extra_configs = configs
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: True</div>

# %%
configs = {
  "fs.azure.account.key.storageaccount1605.blob.core.windows.net": dbutils.secrets.get(scope="azure_storage_account",key="access_key")
}

dbutils.fs.mount(
  source = "wasbs://taxisource@storageaccount1605.blob.core.windows.net/",
  mount_point = "/mnt/storage",
  extra_configs = configs
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: True</div>

# %% [markdown]
# ##Testing mounts

# %%
dbutils.fs.ls("/mnt/datalake/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: [FileInfo(path=&#39;dbfs:/mnt/datalake/GreenTaxiTripData_201812.csv&#39;, name=&#39;GreenTaxiTripData_201812.csv&#39;, size=62056490),
#  FileInfo(path=&#39;dbfs:/mnt/datalake/PaymentTypes.json&#39;, name=&#39;PaymentTypes.json&#39;, size=277),
#  FileInfo(path=&#39;dbfs:/mnt/datalake/RateCodes.json&#39;, name=&#39;RateCodes.json&#39;, size=252),
#  FileInfo(path=&#39;dbfs:/mnt/datalake/TaxiZones.csv&#39;, name=&#39;TaxiZones.csv&#39;, size=12322),
#  FileInfo(path=&#39;dbfs:/mnt/datalake/yellow_tripdata_2018-12.csv&#39;, name=&#39;yellow_tripdata_2018-12.csv&#39;, size=721522221)]</div>

# %%
dbutils.fs.ls("/mnt/storage/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: [FileInfo(path=&#39;dbfs:/mnt/storage/fhv_tripdata_2018-12.csv&#39;, name=&#39;fhv_tripdata_2018-12.csv&#39;, size=1694806758)]</div>
